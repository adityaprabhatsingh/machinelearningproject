# %%
d={"key":"value","key1":"value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
#d.key to overcome this error we can use a config  box which is a dictionary like structure

# %%
from box import ConfigBox

# %%
d2=ConfigBox({'key':"value",'key2':"value2"})

# %%
d2.key
# Out:
# 'value'

# %%
##for eansure box

def get_product(x:int,y:int)-> int :
    return x*y

# %%
get_product(2,3)
get_product(x=2,y=3)
get_product(2,"3")
# Out:
# '33'

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_product(x:int,y:int)-> int:
    return x*y

# %%
#get_product(2,"3")->shoe error 

get_product(2,3)
# Out:
# 6
